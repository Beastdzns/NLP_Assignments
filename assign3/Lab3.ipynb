# %%
# !pip install nltk scikit-learn pandas
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#imports

import nltk
import re
import pandas as pd

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# sample dataset

data = {
    "text": [
        "The battery life is amazing and the setup was very easy!",
        "I am disappointed with the connectivity, it keeps dropping.",
        "The device works as expected but the price is a bit high.",
        "Worst purchase ever, the app crashes every time I open it.",
        "Excellent build quality and very fast response times.",
        "It's an okay product, nothing special but does the job."
    ],
    "label": ["positive", "negative", "neutral", "negative", "positive", "neutral"]
}

df = pd.DataFrame(data)
df
# Out:
#                                                 text     label
# 0  The battery life is amazing and the setup was ...  positive
# 1  I am disappointed with the connectivity, it ke...  negative
# 2  The device works as expected but the price is ...   neutral
# 3  Worst purchase ever, the app crashes every tim...  negative
# 4  Excellent build quality and very fast response...  positive
# 5  It's an okay product, nothing special but does...   neutral

# %%
# Text cleaning function

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    return text

df['clean_text'] = df['text'].apply(clean_text)
df
# Out:
#                                                 text  ...                                         clean_text
# 0  The battery life is amazing and the setup was ...  ...  the battery life is amazing and the setup was ...
# 1  I am disappointed with the connectivity, it ke...  ...  i am disappointed with the connectivity it kee...
# 2  The device works as expected but the price is ...  ...  the device works as expected but the price is ...
# 3  Worst purchase ever, the app crashes every tim...  ...  worst purchase ever the app crashes every time...
# 4  Excellent build quality and very fast response...  ...  excellent build quality and very fast response...
# 5  It's an okay product, nothing special but does...  ...  its an okay product nothing special but does t...
#
# [6 rows x 3 columns]

# %%
# Stop word removal
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = text.split()
    return " ".join([word for word in words if word not in stop_words])

df['no_stopwords'] = df['clean_text'].apply(remove_stopwords)
df
# Out:
#                                                 text  ...                                     no_stopwords
# 0  The battery life is amazing and the setup was ...  ...                  battery life amazing setup easy
# 1  I am disappointed with the connectivity, it ke...  ...         disappointed connectivity keeps dropping
# 2  The device works as expected but the price is ...  ...             device works expected price bit high
# 3  Worst purchase ever, the app crashes every tim...  ...  worst purchase ever app crashes every time open
# 4  Excellent build quality and very fast response...  ...      excellent build quality fast response times
# 5  It's an okay product, nothing special but does...  ...                 okay product nothing special job
#
# [6 rows x 4 columns]

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    words = text.split()
    return " ".join([lemmatizer.lemmatize(word) for word in words])

df['lemmatized_text'] = df['no_stopwords'].apply(lemmatize_text)
df
# Out:
#                                                 text  ...                                lemmatized_text
# 0  The battery life is amazing and the setup was ...  ...                battery life amazing setup easy
# 1  I am disappointed with the connectivity, it ke...  ...        disappointed connectivity keep dropping
# 2  The device works as expected but the price is ...  ...            device work expected price bit high
# 3  Worst purchase ever, the app crashes every tim...  ...  worst purchase ever app crash every time open
# 4  Excellent build quality and very fast response...  ...     excellent build quality fast response time
# 5  It's an okay product, nothing special but does...  ...               okay product nothing special job
#
# [6 rows x 5 columns]

# %%
# Label Encoding
label_encoder = LabelEncoder()
df['encoded_label'] = label_encoder.fit_transform(df['label'])

df[['label', 'encoded_label']]
# Out:
#       label  encoded_label
# 0  positive              2
# 1  negative              0
# 2   neutral              1
# 3  negative              0
# 4  positive              2
# 5   neutral              1

# %%
# TF-IDF Representation
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['lemmatized_text'])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf.get_feature_names_out()
)

tfidf_df
# Out:
#     amazing       app   battery  ...      time      work     worst
# 0  0.447214  0.000000  0.447214  ...  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.408248  0.000000
# 3  0.000000  0.361022  0.000000  ...  0.296043  0.000000  0.361022
# 4  0.000000  0.000000  0.000000  ...  0.344300  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [6 rows x 33 columns]

# %%
# Combine Final Output
final_df = pd.concat([df, tfidf_df], axis=1)
final_df
# Out:
#                                                 text  ...     worst
# 0  The battery life is amazing and the setup was ...  ...  0.000000
# 1  I am disappointed with the connectivity, it ke...  ...  0.000000
# 2  The device works as expected but the price is ...  ...  0.000000
# 3  Worst purchase ever, the app crashes every tim...  ...  0.361022
# 4  Excellent build quality and very fast response...  ...  0.000000
# 5  It's an okay product, nothing special but does...  ...  0.000000
#
# [6 rows x 39 columns]

# %%
# Save Output to File
final_df.to_csv("lab3_output.csv", index=False)
print("File Saved Successfully!")
# Out:
# File Saved Successfully!
